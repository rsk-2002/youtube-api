# %%
api_key = 'AIzaSyCDgIyZhzn_I5EM36HFI2j--liGjR8PQhI'

# %%
from googleapiclient.discovery import build

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
youtube

# %%
res = youtube.channels().list(id='UCpV_X0VrL8-jg3t6wYGS-1g', 
                              part='contentDetails').execute()

# %%
res
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 't4dfk5beS3q1U6voX9NaWEsexLQ',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '4WyyH3EKZmKYp-4BPBnhmtRyIz4',
#    'id': 'UCpV_X0VrL8-jg3t6wYGS-1g',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUpV_X0VrL8-jg3t6wYGS-1g'}}}]}

# %%
res = youtube.playlistItems().list(playlistId='UUpV_X0VrL8-jg3t6wYGS-1g',
                                   part='snippet', 
                                   maxResults=20).execute()

# %%
# res['items'][1]['snippet']['resourceId']['videoId']
videoList = []
for item in res['items']:
    videoId = item['snippet']['resourceId']['videoId']
    videoList.append(videoId)
videoList
# Out:
# ['4vq3TqDpG-c',
#  'A1I1fBXr0rc',
#  'mSCjI5sQuxM',
#  'kjYM3dTKA2c',
#  'xWESODkH-bg',
#  'kxulmN9-bRM',
#  'w0cfbkI5bic',
#  '0RJfKJEXUDg',
#  'k4fEvUlqU3U',
#  'ZOgrhn2Uq0U',
#  'GmG3dXhehJc',
#  'lMbHb5VdlMk',
#  'll3sDLQw-QM',
#  '1Xz9P3PkLkw',
#  'bngSCkvK7dw',
#  'JRdWOAqQaUc',
#  '7MCErZitqjg',
#  'UV1ZF6pyhtM',
#  'B0SG2Q0Jpxg',
#  '3On1Mq_sq9Y']

# %%
vCs = []
for i in videoList:
    res = youtube.videos().list(id=i, part='statistics').execute()
    vC = res['items'][0]['statistics']['viewCount']
    vCs.append(int(vC))

# %%
s = sum(vCs)
s
# Out:
# 5737

# %%
# res['nextPageToken']
# get title 
# res['items'][1]['snippet']['title']
# get the videoId
# res['items'][1]['snippet']['resourceId']['videoId']
# get the thumbnail hq
# res['items'][1]['snippet']['thumbnails']['high']['url']
# len(res['items'])
# res['items']

# %%
def get_channel_videos(channel_id):
    res1 = youtube.channels().list(id=channel_id,part='contentDetails').execute()
    playlist_id = res1['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    videos = []
    next_page_token = None
    while 1:
        res2 = youtube.playlistItems().list(playlistId=playlist_id,
                                           part='snippet',
                                           pageToken=next_page_token,
                                           maxResults=20).execute()
        videos += res2['items']
        next_page_token = res2.get('nextPageToken')
        
        if next_page_token is None:
            break
    return videos

# %%
videos = get_channel_videos('UCpV_X0VrL8-jg3t6wYGS-1g')

# %%
len(videos)
# Out:
# 303

# %%
res = youtube.videos().list(id=videos[0]['snippet']['resourceId']['videoId'], part='statistics').execute()

# %%
res
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'SmJRkpTyAMevBTnYmH1yvpT1MTU',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'mFXp6154WlN3AMS-g3B1c52IYg8',
#    'id': '4vq3TqDpG-c',
#    'statistics': {'viewCount': '60',
#     'likeCount': '7',
#     'favoriteCount': '0',
#     'commentCount': '2'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
# def get_videos_stat(video_ids):
#     stats = []
#     for i in range(0, len(video_ids), 50):
#         res = youtube.videos().list(id=','.join(video_ids[i:i+50]), part='statistics').execute()
#         stats += res['items']
#     return stats

# %%
# video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))

# %%
# stats = get_videos_stat(video_ids)

# %%
# most_liked = sorted(stats, key=lambda x:int(x['statistics']['likeCount']), reverse=True)

# %%
# most_liked
# Out:
# [{'kind': 'youtube#video',
#   'etag': '3b6Phb9pIBk3nTJ9lDrI3hGGpso',
#   'id': 'IBdhwrfgP9c',
#   'statistics': {'viewCount': '59720',
#    'likeCount': '598',
#    'favoriteCount': '0',
#    'commentCount': '82'}},
#  {'kind': 'youtube#video',
#   'etag': 'gjNvq9e9htGSrpWU82bJd5oJn2c',
#   'id': 'AkEnjJ5yWV0',
#   'statistics': {'viewCount': '23541',
#    'likeCount': '481',
#    'favoriteCount': '0',
#    'commentCount': '132'}},
#  {'kind': 'youtube#video',
#   'etag': 'Alfq1qtgQv2-ZyLwdsii6EOR_c4',
#   'id': 'qThD1InmsuI',
#   'statistics': {'viewCount': '15647',
#    'likeCount': '303',
#    'favoriteCount': '0',
#    'commentCount': '76'}},
#  {'kind': 'youtube#video',
#   'etag': 'jmqFMD0H_2OwC-PYWZ7DUt6wEBE',
#   'id': 'HwzE2okhq-M',
#   'statistics': {'viewCount': '19093',
#    'likeCount': '285',
#    'favoriteCount': '0',
#    'commentCount': '64'}},
#  {'kind': 'youtube#video',
#   'etag': '3EhunpFh9tspEcv_qdf932rFksI',
#   'id': 'fnvQ8qQM6NU',
# ...
